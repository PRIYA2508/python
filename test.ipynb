# %% [markdown]
# <a href="https://colab.research.google.com/github/PRIYA2508/python/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"hello world"
# Out:
# 'hello world'

# %%
#airthenatic operations
print(10+5)
print(15-5)
print(2**2)
print(4//2)
print(4/2)
print(4+2**5//5+2)
# Out:
# 15
# 10
# 4
# 2
# 2.0
# 12

# %%
#print non-decimal number
print(0b1010)
print(0X50)
print(0o72)
print(0xff)
# Out:
# 10
# 80
# 58
# 255

# %%
#floating-point datatype
print(1.567e2)
print(1.34E-3)
# Out:
# 156.7
# 0.00134

# %%
#Bollean
name = "priya"
if True:
 print("my name is priya")
else:
  print("my name is not priya ")
# Out:
# my name is priya

# %%
x=2
y=1
print("x =", x)
print("y =",y)
print(x+y)
x=3
y=9
print("x =",x)
print("y =",y)
print("x+y =", x+y)
if y == 1:
  print("same for enitre code")
else:
  print("value of y changed =",y)
# Out:
# x = 2
# y = 1
# 3
# x = 3
# y = 9
# x+y = 12
# value of y changed = 9

# %%
#while loop (print 1-5)
num = 1
while num<=5 :
  print(num)
  num += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#break
num =1
while num<=5 :
  print(num)
  if num == 3 :
    break
  print(num) #here to check which elements are printing
  num +=2
# Out:
# 1
# 1
# 3

# %%
#continue
num = 0
while num<10 :
  num +=1
  if num == 6 :
    continue
  print(num)
# Out:
# 1
# 2
# 3
# 4
# 5
# 7
# 8
# 9
# 10
